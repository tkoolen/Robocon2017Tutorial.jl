# %% [markdown]
# # Setup

# %%
# Check out the robocon2017 branch of RigidBodyDynamics and RigidBodyTreeInspector:
Pkg.checkout("RigidBodyDynamics", "robocon2017")
Pkg.checkout("RigidBodyTreeInspector", "robocon2017")

using RigidBodyDynamics
using StaticArrays
using Plots
using RigidbodyTreeInspector
# Out:
# INFO: Checking out RigidBodyDynamics robocon2017...
# RigidBodyDynamics is dirty, bailing
#
#  in (::Base.Pkg.Entry.##18#20{String,String,Bool,Bool})(::Base.LibGit2.GitRepo) at ./pkg/entry.jl:229
#  in transact(::Base.Pkg.Entry.##18#20{String,String,Bool,Bool}, ::Base.LibGit2.GitRepo) at ./libgit2/libgit2.jl:520
#  in with(::Base.Pkg.Entry.##17#19{String,String,Bool,Bool}, ::Base.LibGit2.GitRepo) at ./libgit2/types.jl:638
#  in checkout(::String, ::String, ::Bool, ::Bool) at ./pkg/entry.jl:227
#  in (::Base.Pkg.Dir.##2#3{Array{Any,1},Base.Pkg.Entry.#checkout,Tuple{String,String,Bool,Bool}})() at ./pkg/dir.jl:31
#  in cd(::Base.Pkg.Dir.##2#3{Array{Any,1},Base.Pkg.Entry.#checkout,Tuple{String,String,Bool,Bool}}, ::String) at ./file.jl:59
#  in #cd#1(::Array{Any,1}, ::Function, ::Function, ::String, ::Vararg{Any,N}) at ./pkg/dir.jl:31
#  in checkout(::String, ::String) at ./pkg/pkg.jl:170

# %% [markdown]
# # Creating a double pendulum `Mechanism`
#
# We're going to create a simple `Mechanism` that represents a [double pendulum](https://en.wikipedia.org/wiki/Double_pendulum). The `Mechanism` type can be thought of as an interconnection of rigid bodies and joints.

# %% [markdown]
# One way of creating a `Mechanism` is by parsing a [URDF](http://wiki.ros.org/urdf) file:

# %%
filename = "doublependulum.urdf"
doublependulum = parse_urdf(Float64, filename)
remove_fixed_joints!(doublependulum) # remove 0-dof joints
# Out:
# Vertex: world (root)
#   Vertex: upper_link, Edge: shoulder
#     Vertex: lower_link, Edge: elbow

# %% [markdown]
# Here are the bodies of our double pendulum:

# %%
collect(bodies(doublependulum))
# Out:
# 3-element Array{RigidBodyDynamics.RigidBody{Float64},1}:
#  RigidBody: "world"
#  RigidBody: "upper_link"
#  RigidBody: "lower_link"

# %% [markdown]
# And here are its joints:

# %%
collect(joints(doublependulum))
# Out:
# 2-element Array{RigidBodyDynamics.Joint{Float64},1}:
#  Joint "shoulder": Revolute joint with axis [0.0,1.0,0.0]
#  Joint "elbow": Revolute joint with axis [0.0,1.0,0.0]

# %% [markdown]
# # The state of a `Mechanism`

# %% [markdown]
# A `Mechanism` stores the joint/rigid body layout, but no state information. State information is separated out into a `MechanismState` object:

# %%
state = MechanismState(Float64, doublependulum)
# Out:
# MechanismState{Float64, Float64, Float64}(…)

# %% [markdown]
# Let's first set the configurations and velocities of the joints:

# %%
shoulder, elbow = (joints(doublependulum)...)
configuration(state, shoulder)[:] = 0.3
configuration(state, elbow)[:] = 0.4
velocity(state, shoulder)[:] = 1.
velocity(state, elbow)[:] = 2.;

# %% [markdown]
# **Important**: a `MechanismState` contains cache variables that depend on the configurations and velocities of the joints. These need to be invalidated when the configurations and velocities are changed. To do this, call

# %%
setdirty!(state)

# %% [markdown]
# The joint configurations and velocities are stored as `Vector`s (denoted $q$ and $v$ respectively in this package) inside the `MechanismState` object:

# %%
@show q = configuration_vector(state)
@show v = velocity_vector(state);
# Out:
# q = configuration_vector(state) = [0.3,0.4]
# v = velocity_vector(state) = [1.0,2.0]

# %% [markdown]
# # Kinematics

# %% [markdown]
# We are now ready to do kinematics. Here's how you transform a point at the origin of the frame after the elbow joint to world frame:

# %%
world = root_body(doublependulum)
transform(state, Point3D(elbow.frameAfter, zeros(SVector{3})), default_frame(world))
# Out:
# Point3D in "world": [-0.29552,0.25,-0.955336]

# %% [markdown]
# Other objects like `Wrench`es, `Twist`s, and `SpatialInertia`s, etc. can be transformed in similar fashion.

# %% [markdown]
# You can also ask for the homogeneous transform to world:

# %%
transform_to_root(state, elbow.frameAfter)
# Out:
# Transform3D from "after_elbow" to "world":
# rotation: 0.7000000000000001 rad about [0.0,1.0,0.0], translation: [-0.29552,0.25,-0.955336]

# %% [markdown]
# Or a relative transform:

# %%
relative_transform(state, elbow.frameAfter, shoulder.frameAfter)
# Out:
# Transform3D from "after_elbow" to "after_shoulder":
# rotation: 0.40000000000000024 rad about [2.65182e-8,1.0,0.0], translation: [0.0,0.1,-1.0]

# %% [markdown]
# Here's the center of mass of the double pendulum:

# %%
center_of_mass(state)
# Out:
# Point3D in "world": [-0.543749,0.2,-1.09892]

# %% [markdown]
# # Dynamics

# %% [markdown]
# A `MechanismState` can also be used to compute quantities related to the dynamics of the `Mechanism`. Here we compute the mass matrix:

# %%
mass_matrix(state)
# Out:
# 2×2 Symmetric{Float64,Array{Float64,2}}:
#  4.50512  2.25106
#  2.25106  1.33

# %% [markdown]
# Here's the documentation for `mass_matrix` by the way:

# %%
?mass_matrix
# Out:
# search: mass_matrix mass_matrix!
# ```julia
# mass_matrix(state)
#
# ```
#
# Compute the joint-space mass matrix (also known as the inertia matrix) of the `Mechanism` in the given state, i.e., the matrix $M(q)$ in the unconstrained joint-space equations of motion
#
# $$
# M(q) \dot{v} + c(q, v, w_\text{ext}) = \tau
# $$
#
# This method implements the composite rigid body algorithm.

# %% [markdown]
# Note that there is also a zero-allocation version, `mass_matrix!` (the `!` at the end of a method is a Julia convention signifying that the function is 'in-place', i.e. modifies its input data).

# %% [markdown]
# We can do inverse dynamics as follows (note again that there is a non-allocating version of this method as well):

# %%
v̇ = [2.; 3.] # the joint acceleration vector, i.e., the time derivative of the joint velocity vector v
inverse_dynamics(state, v̇)
# Out:
# 2-element Array{Float64,1}:
#  23.3164
#  15.2013

# %% [markdown]
# # Simulation

# %% [markdown]
# Let's simulate the double pendulum for 5 seconds, starting from the state we defined earlier. For this, we can use the basic `simulate` function:

# %%
ts, qs, vs = simulate(state, 5.);

# %% [markdown]
# `simulate` returns a vector of times (`ts`) and associated joint configurations (`qs`) and velocities (`vs`).
#
# *Note:* A lower level interface for simulation/ODE integration with more options is also available. Consult the documentation for more information.

# %% [markdown]
# We can plot the trajectories using e.g. Plots.jl:

# %%
plot(ts, collect(q[1] for q in qs), xlabel = "Time [s]", ylabel = "Angle [rad]", lab = "Shoulder")
# Out:
# <script src="/Users/twan/code/julia/RigidBodyDynamics/v0.5/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="14e686d1-67c1-4786-8636-bd1d1ab58162" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('14e686d1-67c1-4786-8636-bd1d1ab58162');
#     Plotly.plot(PLOT, [{"yaxis":"y","y":[-0.9418923839547101,-0.9416830692358528,-0.9414736712174822,-0.9412641899764738,-0.9410546255897425,-0.9408449781342418,-0.9406352476869642,-0.9404254343249402,-0.940215538125239,-0.9400055591649675,-0.9397954975212712,-0.9395853532713327,-0.9393751264923724,-0.9391648172616481,-0.9389544256564548,-0.9387439517541243,-0.9385333956320253,-0.9383227573675633,-0.9381120370381799,-0.9379012347213531,-0.937690350494597,-0.9374793844354615,-0.9372683366215321,-0.9370572071304297,-0.9368459960398108,-0.9366347034273667,-0.9364233293708236,-0.9362118739479427,-0.9360003372365194,-0.9357887193143836,-0.9355770202593993,-0.9353652401494643,-0.9351533790625105,-0.934941437076503,-0.9347294142694405,-0.9345173107193547,-0.9343051265043105,-0.9340928617024054,-0.9338805163917695,-0.9336680906505654,-0.933455584556988,-0.9332429981892638,-0.9330303316256516,-0.9328175849444417,-0.9326047582239555,-0.9323918515425461,-0.9321788649785974,-0.9319657986105241,-0.9317526525167718,-0.9315394267758161,-0.9313261214661636,-0.9311127366663501,-0.9308992724549419,-0.9306857289105347,-0.9304721061117537,-0.9302584041372535,-0.9300446230657176,-0.9298307629758584,-0.9296168239464173,-0.9294028060561639,-0.9291887093838961,-0.9289745340084399,-0.9287602800086493,-0.928545947463406,-0.9283315364516191,-0.9281170470522252,-0.9279024793441877,-0.9276878334064972,-0.9274731093181708,-0.9272583071582523,-0.9270434270058117,-0.926828468939945,-0.9266134330397743,-0.9263983193844474,-0.9261831280531376,-0.9259678591250435,-0.9257525126793887,-0.925537088795422,-0.9253215875524166,-0.9251060090296703,-0.9248903533065055,-0.9246746204622683,-0.9244588105763291,-0.9242429237280816,-0.9240269599969434,-0.9238109194623552,-0.9235948022037809,-0.9233786083007072,-0.9231623378326437,-0.9229459908791223,-0.9227295675196974,-0.9225130678339454,-0.9222964919014646,-0.9220798398018749,-0.921863111614818,-0.9216463074199568,-0.9214294272969751,-0.9212124713255777,-0.9209954395854901,-0.9207783321564584,-0.9205611491182489,-0.920343890550648,-0.920126556533462,-0.9199091471465167,-0.9196916624696577,-0.9194741025827496,-0.9192564675656762,-0.9190387574983403,-0.9188209724606631,-0.9186031125325844,-0.9183851777940623,-0.9181671683250728,-0.91794908420561,-0.9177309255156856,-0.9175126923353285,-0.9172943847445851,-0.9170760028235188,-0.9168575466522096,-0.9166390163107547,-0.9164204118792671,-0.9162017334378765,-0.9159829810667282,-0.9157641548459836,-0.9155452548558198,-0.9153262811764291,-0.9151072338880191,-0.9148881130708123,-0.9146689188050462,-0.9144496511709728,-0.9142303102488585,-0.9140108961189838,-0.9137914088616433,-0.9135718485571455,-0.913352215285812,-0.9131325091279784,-0.912912730163993,-0.9126928784742173,-0.9124729541390255,-0.9122529572388043,-0.9120328878539528,-0.9118127460648823,-0.911592531952016,-0.9113722455957888,-0.9111518870766472,-0.9109314564750489,-0.910710953871463,-0.9104903793463692,-0.9102697329802583,-0.9100490148536311,-0.9098282250469991,-0.9096073636408839,-0.9093864307158168,-0.909165426352339,-0.908944350631001,-0.9087232036323627,-0.908501985436993,-0.9082806961254699,-0.9080593357783798,-0.9078379044763178,-0.9076164022998872,-0.9073948293296991,-0.9071731856463728,-0.9069514713305353,-0.9067296864628208,-0.9065078311238708,-0.906285905394334,-0.9060639093548656,-0.9058418430861279,-0.9056197066687893,-0.9053975001835246,-0.9051752237110146,-0.9049528773319456,-0.9047304611270102,-0.9045079751769057,-0.9042854195623351,-0.9040627943640062,-0.9038400996626315,-0.9036173355389283,-0.9033945020736183,-0.9031715993474273,-0.9029486274410852,-0.9027255864353254,-0.9025024764108853,-0.9022792974485053,-0.9020560496289294,-0.901832733032904,-0.9016093477411788,-0.901385893834506,-0.9011623713936399,-0.9009387804993371,-0.9007151212323561,-0.9004913936734574,-0.9002675979034028,-0.9000437340029557,-0.8998198020528804,-0.8995958021339422,-0.8993717343269073,-0.8991475987125424,-0.8989233953716144,- ...

# %% [markdown]
# We can also show a 3D visualization of the double pendulum using DrakeVisualizer:
